# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# This will download MNIST into ./data if it's not already there
train = datasets.MNIST(root="data", train=True, download=True, transform=ToTensor())
test  = datasets.MNIST(root="data", train=False, download=True, transform=ToTensor())

print(len(train), len(test))
# Out:
# 60000 10000

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

batch_size = 128
val_size = 5000
train_size = len(train) - val_size
generator = torch.Generator().manual_seed(42)
train_subset, val_subset = random_split(train, [train_size, val_size], generator=generator)

train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False)

class MLPClassifier(nn.Module):
    def __init__(self, input_dim=28*28, hidden_dims=(256, 128), num_classes=10):
        super().__init__()
        layers = []
        prev = input_dim
        for h in hidden_dims:
            layers.append(nn.Linear(prev, h))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(0.2))
            prev = h
        layers.append(nn.Linear(prev, num_classes))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        return self.net(x)

model = MLPClassifier().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
print(model)
# Out:
# device: cuda
# MLPClassifier(
#   (net): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
import time

def train_epoch(model, loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * labels.size(0)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    return running_loss / total, correct / total

@torch.no_grad()
def evaluate(model, loader, criterion):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_loss += loss.item() * labels.size(0)
        preds = outputs.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
    return running_loss / total, correct / total

epochs = 5
for epoch in range(1, epochs + 1):
    start_time = time.perf_counter()
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer)
    val_loss, val_acc = evaluate(model, val_loader, criterion)
    epoch_time = time.perf_counter() - start_time
    print(
        f"Epoch {epoch}: train loss {train_loss:.4f}, train acc {train_acc:.4f} | "
        f"val loss {val_loss:.4f}, val acc {val_acc:.4f} | time {epoch_time:.2f}s"
    )
# Out:
# Epoch 1: train loss 0.4031, train acc 0.8844 | val loss 0.1926, val acc 0.9398 | time 6.48s
# Epoch 2: train loss 0.1607, train acc 0.9526 | val loss 0.1251, val acc 0.9614 | time 4.90s
# Epoch 3: train loss 0.1110, train acc 0.9655 | val loss 0.0972, val acc 0.9718 | time 4.83s
# Epoch 4: train loss 0.0890, train acc 0.9720 | val loss 0.0930, val acc 0.9714 | time 5.06s
# Epoch 5: train loss 0.0728, train acc 0.9775 | val loss 0.0865, val acc 0.9732 | time 4.96s

# %%
# Export trained model to ONNX
onnx_path = "mnist_mlp.onnx"
model.eval()
dummy_input = torch.randn(1, 1, 28, 28, device=device)
torch.onnx.export(
    model,
    dummy_input,
    onnx_path,
    input_names=["input"],
    output_names=["logits"],
    dynamic_axes={"input": {0: "batch"}, "logits": {0: "batch"}},
    opset_version=12,
    do_constant_folding=True,
)
print(f"Saved ONNX model to {onnx_path}")
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Saved ONNX model to mnist_mlp.onnx

# %%
onnx_path = "mnist_mlp.onnx"

# %%
import os
import ctypes
import importlib

lib_path = "/usr/lib/x86_64-linux-gnu"
os.environ["LD_LIBRARY_PATH"] = f"{lib_path}:" + os.environ.get("LD_LIBRARY_PATH", "")

try:
    ctypes.CDLL("libpython3.10.so.1.0")
    print("Loaded libpython3.10.so.1.0")
except OSError as e:
    print("Failed to load libpython3.10.so.1.0:", e)

py_libpymo = importlib.import_module("aimet_onnx.common.py_libpymo")
libpymo = importlib.import_module("aimet_onnx.common.libpymo")
defs = importlib.import_module("aimet_onnx.common.defs")
encoding = importlib.import_module("aimet_onnx._encoding")
qc_quantize_op = importlib.import_module("aimet_onnx.qc_quantize_op")
quantsim = importlib.import_module("aimet_onnx.quantsim")
aimet_onnx = importlib.import_module("aimet_onnx")

importlib.reload(py_libpymo)
importlib.reload(libpymo)
importlib.reload(defs)
importlib.reload(encoding)
importlib.reload(qc_quantize_op)
importlib.reload(quantsim)
importlib.reload(aimet_onnx)
# Out:
# Loaded libpython3.10.so.1.0
# <module 'aimet_onnx' from '/home/jovyan/video-proj-storage/mushfiq_files/python3.10/lib/python3.10/site-packages/aimet_onnx/__init__.py'>

# %%
import traceback
try:
    from aimet_onnx.common import libpymo
    print("libpymo loaded:", libpymo)
except Exception as e:
    print("libpymo import error:", repr(e))
    traceback.print_exc()
# Out:
# libpymo loaded: <module 'aimet_onnx.common.libpymo' from '/home/jovyan/video-proj-storage/mushfiq_files/python3.10/lib/python3.10/site-packages/aimet_onnx/common/libpymo.py'>

# %%
import importlib
import traceback
try:
    _libpymo = importlib.import_module("aimet_onnx.common._libpymo")
    print("_libpymo loaded:", _libpymo)
except Exception as e:
    print("_libpymo import error:", repr(e))
    traceback.print_exc()
# Out:
# _libpymo loaded: <module 'aimet_onnx.common._libpymo' from '/home/jovyan/video-proj-storage/mushfiq_files/python3.10/lib/python3.10/site-packages/aimet_onnx/common/_libpymo.cpython-310-x86_64-linux-gnu.so'>

# %%
from aimet_onnx.common import _libpymo
try:
    _ = _libpymo.BlockTensorQuantizer([], 8, _libpymo.QuantizationMode.QUANTIZATION_TF)
    print("BlockTensorQuantizer OK with empty list")
except Exception as e:
    print("BlockTensorQuantizer error with empty list:", repr(e))

try:
    _ = _libpymo.BlockTensorQuantizer([1], 8, _libpymo.QuantizationMode.QUANTIZATION_TF)
    print("BlockTensorQuantizer OK with [1]")
except Exception as e:
    print("BlockTensorQuantizer error with [1]:", repr(e))
# Out:
# BlockTensorQuantizer OK with empty list
# BlockTensorQuantizer OK with [1]

# %%
from aimet_onnx.common import libpymo as libpymo_py
from aimet_onnx.common import _libpymo as libpymo_bin
print("Same BlockTensorQuantizer:", libpymo_py.BlockTensorQuantizer is libpymo_bin.BlockTensorQuantizer)
print("libpymo_py:", libpymo_py)
print("libpymo_bin:", libpymo_bin)
# Out:
# Same BlockTensorQuantizer: True
# libpymo_py: <module 'aimet_onnx.common.libpymo' from '/home/jovyan/video-proj-storage/mushfiq_files/python3.10/lib/python3.10/site-packages/aimet_onnx/common/libpymo.py'>
# libpymo_bin: <module 'aimet_onnx.common._libpymo' from '/home/jovyan/video-proj-storage/mushfiq_files/python3.10/lib/python3.10/site-packages/aimet_onnx/common/_libpymo.cpython-310-x86_64-linux-gnu.so'>

# %%
from aimet_onnx.common import defs as defs_mod
from aimet_onnx.common import libquant_info
from aimet_onnx.qc_quantize_op import QcQuantizeOp

QuantScheme = defs_mod.QuantScheme
try:
    _qi = libquant_info.QcQuantizeInfo()
    _op = QcQuantizeOp(_qi, QuantScheme.post_training_tf)
    print("QcQuantizeOp init OK")
except Exception as e:
    print("QcQuantizeOp init error:", repr(e))
# Out:
# QcQuantizeOp init OK

# %%
from aimet_onnx.common import libquant_info
print("TensorQuantizerOpMode in libquant_info:", hasattr(libquant_info, "TensorQuantizerOpMode"))
if hasattr(libquant_info, "TensorQuantizerOpMode"):
    print("libquant_info.TensorQuantizerOpMode:", libquant_info.TensorQuantizerOpMode)
# Out:
# TensorQuantizerOpMode in libquant_info: False

# %%
import aimet_onnx

# %%
# AIMET ONNX PTQ (calibration-based)
import numpy as np
import onnx
import aimet_onnx
from aimet_onnx import QuantizationSimModel
from aimet_onnx.common.defs import QuantScheme
from enum import Enum

# Load exported ONNX model
model_onnx = onnx.load(onnx_path)

# Optional: simplify ONNX graph
try:
    import onnxsim
    model_onnx, _ = onnxsim.simplify(model_onnx)
    print("ONNX model simplified")
except Exception as e:
    print("onnxsim not available or simplification failed:", e)

# Create QuantSim model (W8A8)
providers = ["CPUExecutionProvider"]
sim = QuantizationSimModel(
    model_onnx,
    param_type=aimet_onnx.int8,
    activation_type=aimet_onnx.int8,
    quant_scheme=QuantScheme.post_training_tf,
    config_file="default",
    providers=providers,
)

input_name = sim.session.get_inputs()[0].name
NUM_CALIBRATION_SAMPLES = 1024
num_batches = max(1, NUM_CALIBRATION_SAMPLES // batch_size)

def onnx_data_generator(num_batches):
    for i, (data, _) in enumerate(train_loader):
        if i >= num_batches:
            break
        yield {input_name: data.numpy()}

# Compute encodings using calibration data (train subset only)
sim.compute_encodings(onnx_data_generator(num_batches))

def eval_onnx_session(session, loader):
    correct = 0
    total = 0
    for inputs, labels in loader:
        outputs = session.run(None, {input_name: inputs.numpy()})[0]
        preds = outputs.argmax(axis=1)
        correct += (preds == labels.numpy()).sum()
        total += labels.shape[0]
    return correct / total

val_acc_quant = eval_onnx_session(sim.session, val_loader)
print(f"Quantized (W8A8) validation accuracy: {val_acc_quant:.4f}")

def _jsonify(obj):
    if isinstance(obj, Enum):
        return obj.name
    if isinstance(obj, dict):
        return {k: _jsonify(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):
        return [_jsonify(v) for v in obj]
    return obj

sim.quant_args = _jsonify(sim.quant_args)

# Export quantized model and encodings
export_path = "."
export_prefix = "mnist_mlp_w8a8"
sim.export(export_path, export_prefix, export_model=True)
print(f"Exported quantized model to {export_prefix}.onnx and encodings file")
# Out:
# ONNX model simplified
# 2026-02-09 04:18:40,150 - Quant - INFO - Selecting DefaultOpInstanceConfigGenerator to compute the specialized config. hw_version:None
# 2026-02-09 04:18:40.155690261 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14041, index: 0, mask: {64, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.157894411 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14048, index: 7, mask: {4, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.157997601 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14049, index: 8, mask: {68, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158146340 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14050, index: 9, mask: {5, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158233760 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14051, index: 10, mask: {69, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158311780 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14052, index: 11, mask: {6, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158449299 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14053, index: 12, mask: {70, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158521049 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14054, index: 13, mask: {7, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158756218 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14056, index: 15, mask: {8, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158791767 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14055, index: 14, mask: {71, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.158948297 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14057, index: 16, mask: {72, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159058936 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14058, index: 17, mask: {9, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159188626 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14059, index: 18, mask: {73, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159283605 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14060, index: 19, mask: {10, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159413855 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14061, index: 20, mask: {74, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159516584 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14062, index: 21, mask: {11, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159649124 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14063, index: 22, mask: {75, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159727124 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14064, index: 23, mask: {12, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159867413 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14065, index: 24, mask: {76, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.159962253 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14066, index: 25, mask: {13, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.160064372 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14067, index: 26, mask: {77, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.160309041 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14069, index: 28, mask: {78, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.160840899 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14074, index: 33, mask: {17, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.160921038 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14068, index: 27, mask: {14, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.161037938 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14071, index: 30, mask: {79, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.161101818 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14070, index: 29, mask: {15, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.161662225 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14080, index: 39, mask: {20, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.162253463 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14076, index: 35, mask: {18, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.163346238 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14079, index: 38, mask: {83, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.163726627 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14078, index: 37, mask: {19, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.163794616 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14101, index: 60, mask: {94, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.163840506 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14073, index: 32, mask: {80, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.165558899 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14115, index: 74, mask: {101, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.165580829 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14081, index: 40, mask: {84, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.165664568 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14112, index: 71, mask: {36, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.165726128 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14077, index: 36, mask: {82, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.165765968 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14084, index: 43, mask: {22, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.165804488 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14092, index: 51, mask: {26, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.166678534 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14083, index: 42, mask: {85, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.168692825 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14087, index: 46, mask: {87, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.169693411 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14086, index: 45, mask: {23, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.169739721 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14100, index: 59, mask: {30, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.170673627 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14088, index: 47, mask: {24, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.171665703 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14113, index: 72, mask: {100, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.172676639 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14091, index: 50, mask: {89, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.173714564 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14090, index: 49, mask: {25, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.173746224 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14106, index: 65, mask: {33, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.173936663 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14089, index: 48, mask: {88, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.176045704 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14098, index: 57, mask: {29, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.176738181 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14093, index: 52, mask: {90, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.177677087 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14096, index: 55, mask: {28, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.178685323 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14117, index: 76, mask: {102, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.179674219 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14103, index: 62, mask: {95, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.183715002 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14097, index: 56, mask: {92, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.183749092 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14099, index: 58, mask: {93, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.187893324 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14114, index: 73, mask: {37, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.189669966 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14109, index: 68, mask: {98, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.191693898 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14085, index: 44, mask: {86, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.195631151 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14082, index: 41, mask: {21, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.196670887 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14095, index: 54, mask: {91, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.199636254 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14104, index: 63, mask: {32, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.208730745 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14094, index: 53, mask: {27, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.210807157 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14118, index: 77, mask: {39, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.222695726 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14116, index: 75, mask: {38, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.224949767 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14105, index: 64, mask: {96, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.225968042 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14102, index: 61, mask: {31, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.226710989 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14108, index: 67, mask: {34, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.226754679 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14111, index: 70, mask: {99, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.230664292 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14107, index: 66, mask: {97, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.230708242 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14110, index: 69, mask: {35, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.237704492 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14120, index: 79, mask: {40, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.270318534 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14119, index: 78, mask: {103, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.270436643 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14121, index: 80, mask: {104, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.272705934 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14123, index: 82, mask: {105, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.270331474 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14122, index: 81, mask: {41, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.273786729 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14138, index: 97, mask: {49, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.274806955 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14142, index: 101, mask: {51, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.279666084 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14143, index: 102, mask: {115, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.283519218 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14134, index: 93, mask: {47, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.284102895 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14136, index: 95, mask: {48, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.284847632 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14135, index: 94, mask: {111, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.297311509 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14140, index: 99, mask: {50, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.297321739 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14141, index: 100, mask: {114, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.298709723 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14137, index: 96, mask: {112, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2026-02-09 04:18:40.303710012 [E:onnxruntime:Default, env.cc:234 ThreadMain] pthread_setaffinity_np failed for thread: 14139, index: 98, mask: {113, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.

# %%
# Final test on quantized ONNX model (CPU timing)
import onnxruntime as ort
import time

quant_onnx_path = "mnist_mlp_w8a16.onnx"
sess = ort.InferenceSession(quant_onnx_path, providers=["CPUExecutionProvider"])
input_name = sess.get_inputs()[0].name

start_time = time.perf_counter()
test_acc_quant = eval_onnx_session(sess, test_loader)
test_time_quant = time.perf_counter() - start_time
print(f"Quantized ONNX test acc: {test_acc_quant:.4f} | time {test_time_quant:.2f}s")

# %%
start_time = time.perf_counter()
test_loss, test_acc = evaluate(model, test_loader, criterion)
test_time = time.perf_counter() - start_time
print(f"Final test: loss {test_loss:.4f}, acc {test_acc:.4f} | time {test_time:.2f}s")
# Out:
# Final test: loss 0.0720, acc 0.9763 | time 0.47s
